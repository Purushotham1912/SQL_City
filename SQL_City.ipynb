# %%
import pandas as pd
import sqlite3 as sql

# %%
con =sql.connect ('/content/drive/MyDrive/sql-murder-mystery.db')

# %%
print(con)

# %%
query1="""
SELECT *
FROM crime_scene_report
WHERE city="SQL City";

"""
pd.read_sql_query(query1,con)
# Out:
#        date     type                                        description  \
# 0  20180215   murder                         REDACTED REDACTED REDACTED
# 1  20180215   murder  Someone killed the guard! He took an arrow to ...
# 2  20170712    theft  A lone hunter stalks the night, firing arrows ...
# 3  20170820    arson  Wield the Hammer of Sol with honor, Titan, it ...
# 4  20171110  robbery  The Gjallarhorn shoulder-mounted rocket system...
# 5  20180103  bribery  Apparently, Cayde thought it necessary to expo...
# 6  20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 7  20180115  assault                                   Report Not Found
# 8  20180115   murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City
# 1  SQL City
# 2  SQL City
# 3  SQL City
# 4  SQL City
# 5  SQL City
# 6  SQL City
# 7  SQL City
# 8  SQL City

# %% [markdown]
# # Finding witness 1

# %%
query2="""
SELECT *
FROM person
WHERE address_street_name="Northwestern Dr"
ORDER BY address_number desc;
"""
pd.read_sql_query(query2,con)
# Out:
#        id                  name  license_id  address_number  \
# 0   14887        Morty Schapiro      118009            4919
# 1   17729        Lasonya Wildey      439686            3824
# 2   53890        Sophie Tiberio      957671            3755
# 3   73368        Torie Thalmann      773862            3697
# 4   96595         Coretta Cubie      303645            3631
# 5   19420           Cody Schiel      890431            3524
# 6   93509        Emmitt Aceuedo      916706            3491
# 7   87456   Leonora Wolfsberger      215868            3483
# 8   36378        Freddie Ellzey      267882            3449
# 9   53076           Boris Bijou      664914            3327
# 10  28360        Rashad Cascone      924517            3212
# 11  23044          Val Portlock      924989            3143
# 12  51114     Christena Saffell      814284            3055
# 13  68690            Yer Modest      852404            3046
# 14  44004           Alison Eska      327797            2951
# ...

# %%
pd.read_sql_query(query2,con)[:1]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %% [markdown]
# # Finding witness 2

# %%
query3="""
SELECT *
FROM person
WHERE address_street_name="Franklin Ave"
ORDER BY address_number desc;
"""
pd.read_sql_query(query3,con)
# Out:
#        id                 name  license_id  address_number  \
# 0   24737           Gema Nantz      273410            3968
# 1   84531       Edgar Mendieta      315790            3881
# 2   36328         Domenic Laun      971080            3809
# 3   34592    Cordell Lindamood      592762            3657
# 4   83003       Wilmer Casella      672050            3564
# 5   78408         Dante Eschen      218173            3447
# 6   70050   Whitney Herkenratt      138462            3445
# 7   36400         Noe Pancoast      895755            3443
# 8   78170          Graig Summy      192325            3387
# 9   78830        Candice Train      814779            3255
# 10  59746        Ronny Gumbert      469722            3197
# 11  52121       Yelena Whitler      427830            3185
# 12  98744        Jordan Myntti      256116            3104
# 13  62520      Mariah Lepetich      450447            3086
# 14  97913       Cameron Dilick      971988            2954
# ...

# %%
pd.read_sql_query(query3,con)[:5]
# Out:
#       id               name  license_id  address_number address_street_name  \
# 0  24737         Gema Nantz      273410            3968        Franklin Ave
# 1  84531     Edgar Mendieta      315790            3881        Franklin Ave
# 2  36328       Domenic Laun      971080            3809        Franklin Ave
# 3  34592  Cordell Lindamood      592762            3657        Franklin Ave
# 4  83003     Wilmer Casella      672050            3564        Franklin Ave
#
#          ssn
# 0  180545802
# 1  458847132
# 2  825329637
# 3  509890333
# 4  569057540

# %%
query3="""
SELECT *
FROM person
WHERE address_street_name="Franklin Ave"
AND name LIKE '%Annabel%'
ORDER BY address_number desc;
"""
pd.read_sql_query(query3,con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# # interviewing witnesses

# %%
query4="""
SELECT *
FROM interview
WHERE person_id IN (14887,16371)
"""
pd.read_sql_query(query4,con)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# # solving clue 2

# %%
query5= """SELECT p.*, gfn.membership_start_date, gfn.membership_status
FROM person as p
INNER JOIN drivers_license as dl on dl.id = p.license_id
INNER JOIN get_fit_now_member as gfn on p.id = gfn.person_id
INNER JOIN get_fit_now_check_in as gfc on gfc.membership_id = gfn.id
WHERE plate_number LIKE '%H42W%'
  AND gender = 'male'
  AND membership_status = 'gold'
  AND gfn.id LIKE '48Z%'
  AND check_in_date = 20180109;
  """

# %%
pd.read_sql_query(query5,con)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn  membership_start_date membership_status
# 0  871539279               20160101              gold

# %% [markdown]
# # JEREMY BOWERS **THE MURDERER**

# %%
insert_data_query = "INSERT INTO solution VALUES (1,'Jeremy Bowers');"

# %%
# Query the data from the 'solution' table
select_query = "SELECT * FROM solution;"
result = pd.read_sql_query(select_query, con)

# Print the result
print(result)
# Out:
#    user                                              value
# 0     0  Congrats, you found the murderer! But wait, th...

# %% [markdown]
# # INTERVIEWING **JEREMY BOWERS**

# %%
query6="""SELECT *FROM interview
WHERE person_id =67318
"""
pd.read_sql_query(query6,con)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# # FINDING THE MASTERMIND

# %% [markdown]
# # SOLVING CLUE 3

# %%
query7="""
SELECT p.*,dl.car_make,dl.car_model,dl.hair_color,dl.height,inc.annual_income
FROM person as p
INNER JOIN income as inc on inc.ssn =p.ssn
INNER JOIN drivers_license as dl on dl.id =p.license_id
INNER JOIN facebook_event_checkin as fec on p.id =fec.person_id
WHERE car_make='Tesla' AND car_model='Model S' AND hair_color='red' AND height BETWEEN 65 AND 67
"""

# %%
pd.read_sql_query(query7,con)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  99716  Miranda Priestly      202298            1883          Golden Ave
# 1  99716  Miranda Priestly      202298            1883          Golden Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn car_make car_model hair_color  height  annual_income
# 0  987756388    Tesla   Model S        red      66         310000
# 1  987756388    Tesla   Model S        red      66         310000
# 2  987756388    Tesla   Model S        red      66         310000

# %% [markdown]
# # MIRANDA PRIESTLY **THE MASTERMIND**

# %%
insert_data_query = "INSERT INTO solution VALUES (1,'Miranda Priestly');"

# %%
# Query the data from the 'solution' table
select_query = "SELECT * FROM solution;"
result = pd.read_sql_query(select_query, con)

# Print the result
print(result)
# Out:
#    user                                              value
# 0     0  Congrats, you found the murderer! But wait, th...
